# %% [markdown]
# # **Extract Region Data From MCA Files**
#
# This notebook shows how to extract region data from MCA files.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')

import os

from src.mca.region_from_mca import get_region
from src.utils.block_dictionary import get_block_id_dictionary, get_block_color_dictionary

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

DATA_PATH = '../data/'
REGION_FILE_PATH = f'{DATA_PATH}region_dataset/test_world/r.5.0.mca'

CHUNK_X, CHUNK_Z = 10, 8
SECTION_Y = 8
CLUSTER_SIZE = 3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       2 sys.path.append('../')
#       4 import os
# ----> 6 from src.mca.region_from_mca import get_region
#       7 from src.utils.block_dictionary import get_block_id_dictionary, get_block_color_dictionary
#       9 os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
#
# ModuleNotFoundError: No module named 'src.mca'

# %%
block_id_dict = get_block_id_dictionary()
block_color_dict = get_block_color_dictionary()
# Out:
# ✅ Loaded 1005 block states from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_id_dict.json.
# ✅ Loaded 1005 block colors from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_color_dict.json.

# %%
region = get_region(REGION_FILE_PATH, block_id_dict=block_id_dict, parallelize_chunks=True)
region.display(block_id_dict, block_color_dict)
# Out:
# 🔄 Processing chunk: 100%|██████████| 1024/1024 [00:06<00:00, 147.11it/s]

# %%
chunk = region.get_chunk(CHUNK_X, CHUNK_Z)
chunk.display()
# Out:
# ✅ Loaded 1005 block states from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_id_dict.json.
# ✅ Loaded 1005 block colors from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_color_dict.json.

# %%
section = chunk.get_section(SECTION_Y)
section.display()
# Out:
# ✅ Loaded 1005 block states from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_id_dict.json.
# ✅ Loaded 1005 block colors from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_color_dict.json.

# %%
section = chunk.get_section(SECTION_Y + 1)
section.display()
# Out:
# ✅ Loaded 1005 block states from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_id_dict.json.
# ✅ Loaded 1005 block colors from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_color_dict.json.

# %%
cluster = region.get_cluster(CHUNK_X- CLUSTER_SIZE // 2, SECTION_Y- CLUSTER_SIZE // 2, CHUNK_Z- CLUSTER_SIZE // 2, CLUSTER_SIZE)
cluster.display()
# Out:
# ✅ Loaded 1005 block states from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_id_dict.json.
# ✅ Loaded 1005 block colors from C:\Users\arnau\Desktop\blocksage\git\blocksage\data\block_color_dict.json.
