# %% [markdown]
# # **Extract Region Data From MCA Files**
#
# This notebook shows how to extract region data from MCA files.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../')

import numpy as np

DATA_PATH = '../data/'
REGION_FILE_PATH = f'{DATA_PATH}r.-1.0.mca' 

from src.utils.display import display_region
from src.mca.extract_data_from_mca import get_region_data
from src.utils.block_dictionary import get_block_id_dictionary, get_block_color_dictionary

# %%
block_id_dict = get_block_id_dictionary()
block_color_dict = get_block_color_dictionary()

region_blocks = get_region_data(REGION_FILE_PATH, block_id_dict=block_id_dict, parallelize_chunks=True)
display_region(region_blocks, block_id_dict=block_id_dict, block_color_dict=block_color_dict, apply_view=True)
# Out:
# ✅ Loaded 1005 block states from C:\Users\arnau\Desktop\blocksage\data\block_id_dict.json.
# ✅ Loaded 1002 block colors from C:\Users\arnau\Desktop\blocksage\data\block_color_dict.json.
# 🔄 Processing chunks: 100%|██████████| 1024/1024 [00:04<00:00, 253.22it/s]
